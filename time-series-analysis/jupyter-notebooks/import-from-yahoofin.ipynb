# %% [markdown]
# # Загрузка данных из Yahoo Finance
#
# Импорт библиотек

# %%
import numpy as np
import pandas as pd 

import yfinance as yf

# настройки визуализация
import matplotlib.pyplot as plt

# %% [markdown]
# ## Пример 1 Apple Inc
# Загрузим дневные данные по ценам акции Apple Inc с [`Yahoo Finance`](https://finance.yahoo.com/) (Ticker `AAPL`) с 1995-01-01 по 2023-12-31 и создадим датафрейм `apple`

# %%
apple = yf.download(tickers='AAPL', start='1995-01-01', end='2023-12-31')
apple

# %% [markdown]
# Визуализируем данные

# %%
apple.plot(subplots=True, title='Apple Inc')

# %% [markdown]
# Визуализируем цену закрытия

# %%
apple['Close'].plot(title='Closing price')

# %% [markdown]
# ## Пример 2: Apple & Google
#
# Загрузим дневные данные по ценам акции Apple Inc и Alphabet Inc. с [`Yahoo Finance`](https://finance.yahoo.com/) (Tickers `AAPL GOOG`) с 2004-01-01 по 2023-12-31 и создадим датафрейм `shares`
#
# Обратим внимание на имена столбцов

# %%
shares = yf.download(tickers='AAPL, GOOG', start='2004-01-01', end='2023-12-31')
shares
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            AAPL        GOOG        AAPL        GOOG        AAPL
# Date
# 2004-01-02    0.321708         NaN    0.380000         NaN    0.388393
# 2004-01-05    0.335163         NaN    0.395893         NaN    0.399821
# 2004-01-06    0.333953         NaN    0.394464         NaN    0.400357
# 2004-01-07    0.341512         NaN    0.403393         NaN    0.407679
# 2004-01-08    0.353153         NaN    0.417143         NaN    0.423750
# ...                ...         ...         ...         ...         ...
# 2023-12-22  193.353287  142.720001  193.600006  142.720001  195.410004
# 2023-12-26  192.803986  142.820007  193.050003  142.820007  193.889999
# 2023-12-27  192.903839  141.440002  193.149994  141.440002  193.500000
# 2023-12-28  193.333298  141.279999  193.580002  141.279999  194.660004
# 2023-12-29  192.284637  140.929993  192.529999  140.929993  194.399994
#
# Price                          Low                    Open              \
# Ticker            GOOG        AAPL        GOOG        AAPL        GOOG
# Date
# 2004-01-02         NaN    0.378214         NaN    0.384821         NaN
# 2004-01-05         NaN    0.382500         NaN    0.382500         NaN
# 2004-01-06         NaN    0.387679         NaN    0.397321         NaN
# 2004-01-07         NaN    0.391607         NaN    0.394643         NaN
# 2004-01-08         NaN    0.404464         NaN    0.407857         NaN
# ...                ...         ...         ...         ...         ...
# 2023-12-22  143.250000  192.970001  142.054993  195.179993  142.130005
# 2023-12-26  143.945007  192.830002  142.500000  193.610001  142.979996
# 2023-12-27  143.320007  191.089996  141.050995  192.490005  142.830002
# 2023-12-28  142.270004  193.169998  140.828003  194.139999  141.850006
# 2023-12-29  141.434998  191.729996  139.899994  193.899994  140.679993
#
# Price          Volume
# Ticker           AAPL        GOOG
# Date
# 2004-01-02  144642400         NaN
# 2004-01-05  395018400         NaN
# 2004-01-06  509348000         NaN
# 2004-01-07  586874400         NaN
# 2004-01-08  460303200         NaN
# ...               ...         ...
# 2023-12-22   37122800  18494700.0
# 2023-12-26   28919300  11170100.0
# 2023-12-27   48087700  17288400.0
# 2023-12-28   34049900  12192500.0
# 2023-12-29   42628800  14872700.0
#
# [5033 rows x 12 columns]

# %%
# цена закрытия
shares['Close']
# Out:
# Ticker            AAPL        GOOG
# Date
# 2004-01-02    0.380000         NaN
# 2004-01-05    0.395893         NaN
# 2004-01-06    0.394464         NaN
# 2004-01-07    0.403393         NaN
# 2004-01-08    0.417143         NaN
# ...                ...         ...
# 2023-12-22  193.600006  142.720001
# 2023-12-26  193.050003  142.820007
# 2023-12-27  193.149994  141.440002
# 2023-12-28  193.580002  141.279999
# 2023-12-29  192.529999  140.929993
#
# [5033 rows x 2 columns]

# %%
# цена закрытия Google
shares['Close', 'GOOG']
# Out:
# Date
# 2004-01-02           NaN
# 2004-01-05           NaN
# 2004-01-06           NaN
# 2004-01-07           NaN
# 2004-01-08           NaN
#                  ...
# 2023-12-22    142.720001
# 2023-12-26    142.820007
# 2023-12-27    141.440002
# 2023-12-28    141.279999
# 2023-12-29    140.929993
# Name: (Close, GOOG), Length: 5033, dtype: float64

# %% [markdown]
#  Визуализация

# %%
shares.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
shares['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
